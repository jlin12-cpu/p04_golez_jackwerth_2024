# %%
import pandas as pd
import os
os.chdir(r"C:\Users\lola\github\p04_golez_jackwerth_2024")

strip = pd.read_parquet("_data/dividend_strip_1y.parquet")
print(strip["date"].min())
print(strip["date"].max())
print(len(strip))
# Out:
# 1996-01-31 00:00:00
# 2024-12-31 00:00:00
# 348

# %%
opt = pd.read_parquet("_data/optionmetrics_spx_monthly.parquet")
print(opt["date"].min())
print(opt["date"].max())
# Out:
# 1996-01-31 00:00:00
# 2024-12-31 00:00:00

# %%
zero = pd.read_parquet("_data/optionmetrics_zero_curve.parquet")
print(zero["date"].min())
print(zero["date"].max())
# Out:
# 1996-01-02 00:00:00
# 2024-12-31 00:00:00

# %%
rf = pd.read_parquet("_data/t_bill_1m_monthly_return.parquet")

print(rf["date"].min())
print(rf["date"].max())
print(len(rf))
# Out:
# 1962-01-31 00:00:00
# 2024-12-31 00:00:00
# 756

# %%
import pandas as pd

market = pd.read_parquet(
    r"C:\Users\lola\github\p04_golez_jackwerth_2024\_data\crsp_market_return.parquet"
)

strip = pd.read_parquet(
    r"C:\Users\lola\github\p04_golez_jackwerth_2024\_data\dividend_strip_1y.parquet"
)

treasury = pd.read_parquet(
    r"C:\Users\lola\github\p04_golez_jackwerth_2024\_data\crsp_treasury_returns.parquet"
)

rf = pd.read_parquet(
    r"C:\Users\lola\github\p04_golez_jackwerth_2024\_data\t_bill_1m_monthly_return.parquet"
)

# %%
print(market["date"].head())
print(strip["date"].head())
print(treasury["date"].head())
print(rf["date"].head())
# Out:
# 0   1996-01-31
# 1   1996-02-29
# 2   1996-03-29
# 3   1996-04-30
# 4   1996-05-31
# Name: date, dtype: datetime64[ns]
# 0   1996-01-31
# 1   1996-02-29
# 2   1996-03-29
# 3   1996-04-30
# 4   1996-05-31
# Name: date, dtype: datetime64[ns]
# 0   1925-12-31
# 1   1926-01-30
# 2   1926-02-27
# 3   1926-03-31
# 4   1926-04-30
# Name: date, dtype: datetime64[ns]
# 0   1962-01-31
# 1   1962-02-28
# 2   1962-03-31
# 3   1962-04-30
# 4   1962-05-31
# Name: date, dtype: datetime64[ns]

# %%
import pandas as pd
market = pd.read_parquet("_data/crsp_market_return.parquet")
print(market.columns)
print(market.head())
# Out:
# Index(['date', 'market_ret'], dtype='object')
#         date  market_ret
# 0 1996-01-31    0.028121
# 1 1996-02-29    0.016353
# 2 1996-03-29    0.010914
# 3 1996-04-30    0.025560
# 4 1996-05-31    0.026810

# %%
print(strip.columns)
print(rf.columns)
# Out:
# Index(['date', 'strip_price', 'strip_ret'], dtype='object')
# Index(['date', 'tbill_1m_ret'], dtype='object')
